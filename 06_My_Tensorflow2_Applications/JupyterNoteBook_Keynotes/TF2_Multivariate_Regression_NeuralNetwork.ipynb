# %% [markdown]
# # Tensorflow2 KeyNotes
# ### ==== Neural Network based Multivariate Regression (TF2) ====
# ### Instructions
#
# These serial notebooks are intended to record my practicing and keynotes with deep learning in the framework of TensorFlow 2. Within these notebooks, I demonstrate the networks with specific examples and my personal interpretations.  You can find instructions in each section for each project.  Feel free to refer to it if is helpful for your work.
#
# In this notebook, I demonstrate an example of using least square regression and dense neural network based regression method to solve the multivariate regression problem. The analytic 2D Frank function is used in this experiment. The following contents are included in this notebook:
#
# 1. Data simulation with 2D Frank function
# 2. Least square regression with up to 5th order of multivariables.
# 3. Dense neural network based Multivariate Regression.
# 4. Quantitative comparison.
#
# ### Code by Hao, Zhao, Oct, 2020.

# %% [markdown]
# ### Import the tensorflow library

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.2.0

# %% [markdown]
# ###  Load the external libraries

# %%
import numpy as np
import tensorflow as tf
import time

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.layers import Dense,BatchNormalization,Dropout,Conv1D,SimpleRNN,AveragePooling1D,Flatten
from random import random, seed
from sklearn.model_selection import train_test_split

# %% [markdown]
# ###  Using 2D Franke function for multivariate regression experiment

# %%
fig = plt.figure(1,figsize=(15,5))
ax = fig.gca(projection='3d')

# Make data.
x = np.arange(0, 1, 0.01)
y = np.arange(0, 1, 0.01)
x, y = np.meshgrid(x,y)


def FrankeFunction(x,y):
    term1 = 0.75*np.exp(-(0.25*(9*x-2)**2) - 0.25*((9*y-2)**2))
    term2 = 0.75*np.exp(-((9*x+1)**2)/49.0 - 0.1*(9*y+1))
    term3 = 0.5*np.exp(-(9*x-7)**2/4.0 - 0.25*((9*y-3)**2))
    term4 = -0.2*np.exp(-(9*x-4)**2 - (9*y-7)**2)
    return term1 + term2 + term3 + term4


z = FrankeFunction(x, y)

# Plot the surface.
surf = ax.plot_surface(x, y, z, cmap=cm.rainbow,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-0.10, 1.40)
ax.view_init(20, 30)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
ax.set_title(' === Generated Analytic Franke Function=== ')

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %% [markdown]
# ------------------------------------------
# ##  Method-1: Least-square multivariate regression
# ------------------------------------------

# %%
# create 1-d vector for x, y and z
x_vec = x.reshape(x.size,1) 
y_vec = y.reshape(y.size,1)
z_vec = z.reshape(z.size,1)

# generate the design matrix 

def design_matrix_set(x=x_vec,y=y_vec,BaseNumber=21):
    
    # define the design matrix up to 5th order of multivariables x and y (21 bases in total) 
    A_matrix_full = np.c_[np.ones(x.shape), x, y, x**2, y**2, x*y, x**3, y**3, x**2*y, x*y**2, x**4, y**4, x**3*y, x**2*y**2, x*y**3, x**5, y**5, x**4*y, x**3*y**2, x**2*y**3, x*y**4]            

    # select the number of bases for output
    A_matrix = A_matrix_full[:,:BaseNumber]
    
    return A_matrix
        
            
# derive model parameters Beta
array_A = design_matrix_set(x_vec,y_vec,BaseNumber=21)
beta    = np.linalg.inv(array_A.T.dot(array_A)).dot(array_A.T).dot(z_vec)

# generate the predicted z values based on derived model
zpredict = array_A.dot(beta)
zpredict = zpredict.reshape(z.shape)

# plot the derived prediction
fig = plt.figure(2,figsize=(15,5))
ax  = fig.gca(projection='3d')

# Plot the surface.
surf = ax.plot_surface(x, y, zpredict, cmap=cm.rainbow,linewidth=0, antialiased=False)
# Customize the z axis.
ax.set_zlim(-0.10, 1.40)
ax.view_init(20, 30)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
ax.set_title(' === Fitted function by using least-square-regression  === ')

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %% [markdown]
# ------------------------------------------
# ##  Method-2: Dense neural network based multivariate regression
# ------------------------------------------

# %% [markdown]
# ### Data preparation for the Neural Network training and testing

# %%
def dataset_batch_generation(x,y,z,trainset_ratio):
    input  = np.concatenate((x,y),axis=1)
    target = z
    
    # split data into train and test set
    train_input,test_input, train_target,test_target = train_test_split(input, target, train_size=trainset_ratio, random_state=50)
    
    return train_input,train_target,test_input,test_target
    

train_input,train_target,test_input,test_target = dataset_batch_generation(x_vec,y_vec,z_vec,0.9)

# %% [markdown]
# ### Build a dense neural network

# %%
model = Sequential([Dense(64,activation='relu',input_shape=(2,)),
                    Dense(128,activation='relu'),
                    Dense(1)
                    ])

model.compile(optimizer=tf.keras.optimizers.Adam(),loss='mse',metrics=['mae'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                192
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 8,641
# Trainable params: 8,641
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the neural network

# %%
start      = time.time()
history    = model.fit(train_input,train_target,batch_size=64,epochs=100,validation_split=0.10,verbose=1)
trian_time = time.time()-start
print("Training completed in : {:0.2f}ms".format(1000*trian_time))
# Out:
# Epoch 1/100
# 127/127 [==============================] - 0s 2ms/step - loss: 0.0672 - mae: 0.1763 - val_loss: 0.0104 - val_mae: 0.0852
# Epoch 2/100
# 127/127 [==============================] - 0s 1ms/step - loss: 0.0068 - mae: 0.0663 - val_loss: 0.0054 - val_mae: 0.0555
# Epoch 3/100
# 127/127 [==============================] - 0s 1ms/step - loss: 0.0040 - mae: 0.0502 - val_loss: 0.0031 - val_mae: 0.0442
# Epoch 4/100
# 127/127 [==============================] - 0s 1ms/step - loss: 0.0026 - mae: 0.0391 - val_loss: 0.0021 - val_mae: 0.0342
# Epoch 5/100
# 127/127 [==============================] - 0s 1ms/step - loss: 0.0022 - mae: 0.0348 - val_loss: 0.0018 - val_mae: 0.0309
# Epoch 6/100
# 127/127 [==============================] - 0s 1ms/step - loss: 0.0018 - mae: 0.0296 - val_loss: 0.0016 - val_mae: 0.0280
# Epoch 7/100
# 127/127 [==============================] - 0s 1ms/step - loss: 0.0017 - mae: 0.0276 - val_loss: 0.0015 - val_mae: 0.0264
# Epoch 8/100
# 127/127 [==============================] - 0s 1ms/step - loss: 0.0016 - mae: 0.0274 - val_loss: 0.0015 - val_mae: 0.0267
# Epoch 9/100
# 127/127 [==============================] - 0s 1ms/step - loss: 0.0015 - mae: 0.0264 - val_loss: 0.0014 - val_mae: 0.0251
# Epoch 10/100
# 127/127 [==============================] - 0s 1ms/step - loss: 0.0015 - mae: 0.0258 - val_loss: 0.0014 - val_mae: 0.0249
# Epoch 11/100
# 127/127 [==============================] - 0s 1ms/step - loss: 0.0015 - mae: 0.0255 - val_loss: 0.0021 - val_mae: 0.0356
# Epoch 12/100
# 127/127 [==============================] - 0s 1ms/step - loss: 0.0016 - mae: 0.0280 - val_loss: 0.0017 - val_mae: 0.0315
# Epoch 13/100
# 127/127 [==============================] - 0s 1ms/step - loss: 0.0013 - mae: 0.0242 - val_loss: 0.0012 - val_mae: 0.0221
# Epoch 14/100
# 127/127 [==============================] - 0s 1ms/step - loss: 0.0012 - mae: 0.0233 - val_loss: 0.0010 - val_mae: 0.0205
# Epoch 15/100
# 127/127 [==============================] - 0s 1ms/step - loss: 0.0011 - mae: 0.0216 - val_loss: 9.0132e-04 - val_mae: 0.0195
# Epoch 16/100
# 127/127 [==============================] - 0s 1ms/step - loss: 9.5242e-04 - mae: 0.0199 - val_loss: 7.9134e-04 - val_mae: 0.0179
# Epoch 17/100
# 127/127 [==============================] - 0s 1ms/step - loss: 8.2815e-04 - mae: 0.0186 - val_loss: 6.3787e-04 - val_mae: 0.0163
# Epoch 18/100
# 127/127 [==============================] - 0s 1ms/step - loss: 7.3600e-04 - mae: 0.0180 - val_loss: 6.9012e-04 - val_mae: 0.0193
# Epoch 19/100
# 127/127 [==============================] - 0s 1ms/step - loss: 6.3181e-04 - mae: 0.0172 - val_loss: 4.8431e-04 - val_mae: 0.0148
# Epoch 20/100
# 127/127 [==============================] - 0s 1ms/step - loss: 5.3634e-04 - mae: 0.0160 - val_loss: 4.1331e-04 - val_mae: 0.0135
# Epoch 21/100
# 127/127 [==============================] - 0s 1ms/step - loss: 4.7155e-04 - mae: 0.0153 - val_loss: 4.1374e-04 - val_mae: 0.0151
# Epoch 22/100
# 127/127 [==============================] - 0s 1ms/step - loss: 4.0787e-04 - mae: 0.0143 - val_loss: 3.0173e-04 - val_mae: 0.0122
# Epoch 23/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.8241e-04 - mae: 0.0143 - val_loss: 3.0856e-04 - val_mae: 0.0135
# Epoch 24/100
# 127/127 [==============================] - 0s 1ms/step - loss: 2.9853e-04 - mae: 0.0125 - val_loss: 2.6121e-04 - val_mae: 0.0118
# Epoch 25/100
# 127/127 [==============================] - 0s 1ms/step - loss: 2.5891e-04 - mae: 0.0118 - val_loss: 2.0714e-04 - val_mae: 0.0103
# Epoch 26/100
# 127/127 [==============================] - 0s 1ms/step - loss: 2.3665e-04 - mae: 0.0115 - val_loss: 1.9138e-04 - val_mae: 0.0099
# Epoch 27/100
# 127/127 [==============================] - 0s 1ms/step - loss: 2.2476e-04 - mae: 0.0112 - val_loss: 1.5577e-04 - val_mae: 0.0092
# Epoch 28/100
# 127/127 [==============================] - 0s 1ms/step - loss: 1.8453e-04 - mae: 0.0102 - val_loss: 1.7009e-04 - val_mae: 0.0095
# Epoch 29/100
# 127/127 [==============================] - 0s 1ms/step - loss: 1.5305e-04 - mae: 0.0093 - val_loss: 1.3364e-04 - val_mae: 0.0084
# Epoch 30/100
# 127/127 [==============================] - 0s 1ms/step - loss: 1.4272e-04 - mae: 0.0091 - val_loss: 1.4452e-04 - val_mae: 0.0094
# Epoch 31/100
# 127/127 [==============================] - 0s 1ms/step - loss: 1.2587e-04 - mae: 0.0085 - val_loss: 1.1076e-04 - val_mae: 0.0080
# Epoch 32/100
# 127/127 [==============================] - 0s 1ms/step - loss: 1.3458e-04 - mae: 0.0089 - val_loss: 9.6211e-05 - val_mae: 0.0072
# Epoch 33/100
# 127/127 [==============================] - 0s 1ms/step - loss: 8.8408e-05 - mae: 0.0071 - val_loss: 8.6301e-05 - val_mae: 0.0070
# Epoch 34/100
# 127/127 [==============================] - 0s 1ms/step - loss: 8.4098e-05 - mae: 0.0069 - val_loss: 7.8264e-05 - val_mae: 0.0065
# Epoch 35/100
# 127/127 [==============================] - 0s 1ms/step - loss: 7.5832e-05 - mae: 0.0066 - val_loss: 6.3552e-05 - val_mae: 0.0059
# Epoch 36/100
# 127/127 [==============================] - 0s 1ms/step - loss: 7.7000e-05 - mae: 0.0067 - val_loss: 6.0011e-05 - val_mae: 0.0057
# Epoch 37/100
# 127/127 [==============================] - 0s 1ms/step - loss: 7.5239e-05 - mae: 0.0067 - val_loss: 6.1340e-05 - val_mae: 0.0062
# Epoch 38/100
# 127/127 [==============================] - 0s 1ms/step - loss: 6.5151e-05 - mae: 0.0062 - val_loss: 7.6691e-05 - val_mae: 0.0068
# Epoch 39/100
# 127/127 [==============================] - 0s 1ms/step - loss: 6.2691e-05 - mae: 0.0060 - val_loss: 4.8895e-05 - val_mae: 0.0054
# Epoch 40/100
# 127/127 [==============================] - 0s 1ms/step - loss: 5.9471e-05 - mae: 0.0059 - val_loss: 5.3222e-05 - val_mae: 0.0056
# Epoch 41/100
# 127/127 [==============================] - 0s 1ms/step - loss: 5.8003e-05 - mae: 0.0059 - val_loss: 7.8452e-05 - val_mae: 0.0070
# Epoch 42/100
# 127/127 [==============================] - 0s 1ms/step - loss: 5.9019e-05 - mae: 0.0060 - val_loss: 4.5230e-05 - val_mae: 0.0051
# Epoch 43/100
# 127/127 [==============================] - 0s 1ms/step - loss: 5.1882e-05 - mae: 0.0055 - val_loss: 4.6120e-05 - val_mae: 0.0052
# Epoch 44/100
# 127/127 [==============================] - 0s 1ms/step - loss: 7.6915e-05 - mae: 0.0069 - val_loss: 1.8034e-04 - val_mae: 0.0113
# Epoch 45/100
# 127/127 [==============================] - 0s 1ms/step - loss: 6.0809e-05 - mae: 0.0061 - val_loss: 4.3528e-05 - val_mae: 0.0051
# Epoch 46/100
# 127/127 [==============================] - 0s 1ms/step - loss: 6.0289e-05 - mae: 0.0060 - val_loss: 3.5865e-05 - val_mae: 0.0045
# Epoch 47/100
# 127/127 [==============================] - 0s 1ms/step - loss: 5.8334e-05 - mae: 0.0060 - val_loss: 6.0335e-05 - val_mae: 0.0062
# Epoch 48/100
# 127/127 [==============================] - 0s 1ms/step - loss: 5.6636e-05 - mae: 0.0059 - val_loss: 7.4869e-05 - val_mae: 0.0069
# Epoch 49/100
# 127/127 [==============================] - 0s 1ms/step - loss: 5.0490e-05 - mae: 0.0055 - val_loss: 5.5901e-05 - val_mae: 0.0060
# Epoch 50/100
# 127/127 [==============================] - 0s 1ms/step - loss: 5.0020e-05 - mae: 0.0056 - val_loss: 4.6348e-05 - val_mae: 0.0053
# Epoch 51/100
# 127/127 [==============================] - 0s 1ms/step - loss: 5.9660e-05 - mae: 0.0059 - val_loss: 5.0922e-05 - val_mae: 0.0059
# Epoch 52/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.9340e-05 - mae: 0.0048 - val_loss: 3.1588e-05 - val_mae: 0.0043
# Epoch 53/100
# 127/127 [==============================] - 0s 1ms/step - loss: 4.1835e-05 - mae: 0.0050 - val_loss: 3.5955e-05 - val_mae: 0.0046
# Epoch 54/100
# 127/127 [==============================] - 0s 1ms/step - loss: 4.8091e-05 - mae: 0.0054 - val_loss: 4.2597e-05 - val_mae: 0.0053
# Epoch 55/100
# 127/127 [==============================] - 0s 1ms/step - loss: 4.0370e-05 - mae: 0.0049 - val_loss: 3.6325e-05 - val_mae: 0.0047
# Epoch 56/100
# 127/127 [==============================] - 0s 1ms/step - loss: 4.7763e-05 - mae: 0.0054 - val_loss: 4.6874e-05 - val_mae: 0.0056
# Epoch 57/100
# 127/127 [==============================] - 0s 1ms/step - loss: 5.4379e-05 - mae: 0.0058 - val_loss: 6.3711e-05 - val_mae: 0.0065
# Epoch 58/100
# 127/127 [==============================] - 0s 1ms/step - loss: 4.3659e-05 - mae: 0.0052 - val_loss: 2.6848e-05 - val_mae: 0.0039
# Epoch 59/100
# 127/127 [==============================] - 0s 1ms/step - loss: 4.3715e-05 - mae: 0.0052 - val_loss: 4.1220e-05 - val_mae: 0.0050
# Epoch 60/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.5484e-05 - mae: 0.0046 - val_loss: 2.9800e-05 - val_mae: 0.0042
# Epoch 61/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.8848e-05 - mae: 0.0048 - val_loss: 9.0908e-05 - val_mae: 0.0078
# Epoch 62/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.8088e-05 - mae: 0.0048 - val_loss: 3.5731e-05 - val_mae: 0.0047
# Epoch 63/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.7146e-05 - mae: 0.0048 - val_loss: 9.4954e-05 - val_mae: 0.0079
# Epoch 64/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.7601e-05 - mae: 0.0047 - val_loss: 2.4574e-05 - val_mae: 0.0039
# Epoch 65/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.7335e-05 - mae: 0.0048 - val_loss: 3.2466e-05 - val_mae: 0.0043
# Epoch 66/100
# 127/127 [==============================] - 0s 2ms/step - loss: 4.4268e-05 - mae: 0.0052 - val_loss: 3.4830e-05 - val_mae: 0.0046
# Epoch 67/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.6019e-05 - mae: 0.0047 - val_loss: 2.4857e-05 - val_mae: 0.0037
# Epoch 68/100
# 127/127 [==============================] - 0s 1ms/step - loss: 4.4904e-05 - mae: 0.0052 - val_loss: 4.3290e-05 - val_mae: 0.0052
# Epoch 69/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.2400e-05 - mae: 0.0045 - val_loss: 2.3425e-05 - val_mae: 0.0037
# Epoch 70/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.0135e-05 - mae: 0.0042 - val_loss: 2.6536e-05 - val_mae: 0.0040
# Epoch 71/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.2068e-05 - mae: 0.0044 - val_loss: 3.0322e-05 - val_mae: 0.0043
# Epoch 72/100
# 127/127 [==============================] - 0s 1ms/step - loss: 4.4241e-05 - mae: 0.0053 - val_loss: 2.9174e-05 - val_mae: 0.0042
# Epoch 73/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.8717e-05 - mae: 0.0049 - val_loss: 5.4493e-05 - val_mae: 0.0057
# Epoch 74/100
# 127/127 [==============================] - 0s 1ms/step - loss: 5.2722e-05 - mae: 0.0058 - val_loss: 5.3450e-05 - val_mae: 0.0061
# Epoch 75/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.4291e-05 - mae: 0.0046 - val_loss: 3.7031e-05 - val_mae: 0.0048
# Epoch 76/100
# 127/127 [==============================] - 0s 1ms/step - loss: 4.2829e-05 - mae: 0.0052 - val_loss: 4.4612e-05 - val_mae: 0.0055
# Epoch 77/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.7918e-05 - mae: 0.0048 - val_loss: 3.3803e-05 - val_mae: 0.0045
# Epoch 78/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.8018e-05 - mae: 0.0049 - val_loss: 2.5560e-05 - val_mae: 0.0040
# Epoch 79/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.2617e-05 - mae: 0.0045 - val_loss: 2.1214e-05 - val_mae: 0.0035
# Epoch 80/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.0059e-05 - mae: 0.0043 - val_loss: 3.8342e-05 - val_mae: 0.0052
# Epoch 81/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.0760e-05 - mae: 0.0043 - val_loss: 2.4041e-05 - val_mae: 0.0039
# Epoch 82/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.1580e-05 - mae: 0.0044 - val_loss: 3.0811e-05 - val_mae: 0.0045
# Epoch 83/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.7821e-05 - mae: 0.0049 - val_loss: 7.6822e-05 - val_mae: 0.0072
# Epoch 84/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.7698e-05 - mae: 0.0049 - val_loss: 3.3694e-05 - val_mae: 0.0048
# Epoch 85/100
# 127/127 [==============================] - 0s 1ms/step - loss: 2.7967e-05 - mae: 0.0042 - val_loss: 3.5669e-05 - val_mae: 0.0048
# Epoch 86/100
# 127/127 [==============================] - 0s 2ms/step - loss: 2.6732e-05 - mae: 0.0040 - val_loss: 2.9147e-05 - val_mae: 0.0044
# Epoch 87/100
# 127/127 [==============================] - 0s 1ms/step - loss: 2.5246e-05 - mae: 0.0040 - val_loss: 5.6505e-05 - val_mae: 0.0064
# Epoch 88/100
# 127/127 [==============================] - 0s 1ms/step - loss: 5.6398e-05 - mae: 0.0059 - val_loss: 9.5995e-05 - val_mae: 0.0086
# Epoch 89/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.0185e-05 - mae: 0.0043 - val_loss: 5.1359e-05 - val_mae: 0.0060
# Epoch 90/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.6637e-05 - mae: 0.0048 - val_loss: 4.5955e-05 - val_mae: 0.0055
# Epoch 91/100
# 127/127 [==============================] - 0s 1ms/step - loss: 2.6761e-05 - mae: 0.0041 - val_loss: 2.7445e-05 - val_mae: 0.0042
# Epoch 92/100
# 127/127 [==============================] - 0s 1ms/step - loss: 2.7666e-05 - mae: 0.0041 - val_loss: 3.6123e-05 - val_mae: 0.0048
# Epoch 93/100
# 127/127 [==============================] - 0s 1ms/step - loss: 2.7564e-05 - mae: 0.0042 - val_loss: 1.9776e-05 - val_mae: 0.0035
# Epoch 94/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.0274e-05 - mae: 0.0043 - val_loss: 1.7920e-05 - val_mae: 0.0033
# Epoch 95/100
# 127/127 [==============================] - 0s 1ms/step - loss: 2.5445e-05 - mae: 0.0040 - val_loss: 3.2026e-05 - val_mae: 0.0045
# Epoch 96/100
# 127/127 [==============================] - 0s 1ms/step - loss: 2.7064e-05 - mae: 0.0041 - val_loss: 3.9917e-05 - val_mae: 0.0055
# Epoch 97/100
# 127/127 [==============================] - 0s 1ms/step - loss: 2.6908e-05 - mae: 0.0041 - val_loss: 2.4530e-05 - val_mae: 0.0041
# Epoch 98/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.3693e-05 - mae: 0.0046 - val_loss: 5.6567e-05 - val_mae: 0.0064
# Epoch 99/100
# 127/127 [==============================] - 0s 1ms/step - loss: 3.0441e-05 - mae: 0.0044 - val_loss: 2.0675e-05 - val_mae: 0.0035
# Epoch 100/100
# 127/127 [==============================] - 0s 1ms/step - loss: 2.7959e-05 - mae: 0.0042 - val_loss: 1.8730e-05 - val_mae: 0.0034
# Training completed in : 18702.03ms

# %% [markdown]
# ### Display of training and validation losses in the network training

# %%
plt.figure(3,figsize=(10, 5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.grid(color='k', linestyle='-', linewidth=0.1)
plt.show()

# %% [markdown]
# ### Prediction with test dataset

# %%
dnn_predictions = model.predict(test_input)

plt.figure(4,figsize=(10, 5))
plt.plot(test_target[:100],'r',label='Test target')
plt.plot(dnn_predictions[:100],'b',label='Dnn_predictions')
plt.grid(color='k', linestyle='-', linewidth=0.1)
plt.legend(loc='upper left')

# %% [markdown]
# ----------------------------------------------------------------------
# ## Comparison of two methods
# ----------------------------------------------------------------------

# %% [markdown]
# ### Compare the loss in the finner grid

# %%
x_qc = np.arange(0, 1, 0.001)
y_qc = np.arange(0, 1, 0.001)
x_qc, y_qc = np.meshgrid(x_qc,y_qc)
z_qc       = FrankeFunction(x_qc, y_qc) 

# generate the predicted z values bsed on derived regression model
array_A_qc  = design_matrix_set(x_qc.reshape(x_qc.size,1),y_qc.reshape(y_qc.size,1),BaseNumber=21)
zpredict_qc = array_A_qc.dot(beta)
zpredict_qc = zpredict_qc.reshape(z_qc.shape)

# generate the predicted z values based on derived neural network model
zpredictNN_qc = model.predict(np.concatenate((x_qc.reshape(x_qc.size,1),y_qc.reshape(y_qc.size,1)),axis=1))
zpredictNN_qc = zpredictNN_qc.reshape(z_qc.shape)

# %% [markdown]
# ### Plot the 3D results

# %%
fig = plt.figure(5,figsize=(15, 5))

ax = fig.add_subplot(1,3,1,projection='3d')
surf = ax.plot_surface(x_qc, y_qc, z_qc, cmap=cm.rainbow,linewidth=0, antialiased=False)
ax.set_zlim(-0.10, 1.40)
ax.view_init(20, 30)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
ax.set_title('Analytic 2D model')

ax = fig.add_subplot(1,3,2,projection='3d')
surf = ax.plot_surface(x_qc, y_qc, zpredict_qc, cmap=cm.rainbow,linewidth=0, antialiased=False)
ax.set_zlim(-0.10, 1.40)
ax.view_init(20, 30)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
ax.set_title('Fitted model derived by Least-square-regression')

ax = fig.add_subplot(1,3,3,projection='3d')
surf = ax.plot_surface(x_qc, y_qc, zpredictNN_qc, cmap=cm.rainbow,linewidth=0, antialiased=False)
ax.set_zlim(-0.10, 1.40)
ax.view_init(20, 30)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
ax.set_title('Fitted model derived by dense neural network')
# Out:
# Text(0.5, 0.92, 'Fitted model derived by dense neural network')

# %%
# plot the 3D results (projection view angle)
fig = plt.figure(6,figsize=(15,5))

ax = fig.add_subplot(1,3,1,projection='3d')
surf = ax.plot_surface(x_qc, y_qc, z_qc, cmap=cm.rainbow,linewidth=0, antialiased=False)
ax.set_zlim(-0.10, 1.40)
ax.view_init(75,45)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
ax.set_title('Analytic 2D model')


ax = fig.add_subplot(1,3,2,projection='3d')
surf = ax.plot_surface(x_qc, y_qc, zpredict_qc, cmap=cm.rainbow,linewidth=0, antialiased=False)
ax.set_zlim(-0.10, 1.40)
ax.view_init(75,45)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
ax.set_title('Fitted model derived by Least-square-regression')


ax = fig.add_subplot(1,3,3,projection='3d')
surf = ax.plot_surface(x_qc, y_qc, zpredictNN_qc, cmap=cm.rainbow,linewidth=0, antialiased=False)
ax.set_zlim(-0.10, 1.40)
ax.view_init(75,45)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
ax.set_title('Fitted model derived by dense neural network')

plt.show()

# %% [markdown]
# ### Mean square error comparison
